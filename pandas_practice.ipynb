# %%
import numpy as np
import pandas as pd

df = pd.read_csv("datas/immo_data.csv")
df.head()
# Out:
#               locality   Price       Type_property Sale_type Number_bedrooms  \
# 0   libramont-chevigny  145500           apartment  for-sale               1
# 1  la-roche-en-ardenne  185000  mixed-use-building  for-sale               4
# 2               manhay  228000           apartment  for-sale               4
# 3              bertrix  249500               house  for-sale               3
# 4         saint-hubert  295000               house  for-sale               6
#
#   Living_area fully_equipped_kitchen Furnished terrace garden surface_land  \
# 0          40                      1         0       8   None           40
# 1         226                      1      None    None   None          226
# 2         290                      0         0    None    300          290
# 3         176                      1         0      18    620          176
# 4         229                      1         0    None   None          229
#
# ...

# %%
df.shape
df.columns.to_list()
df.describe()
df.max() # max of all columns 
df['Price'].max(numeric_only=True)
# Out:
# C:\Users\meule\AppData\Local\Temp\ipykernel_11872\1340896382.py:4: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max() # max of all columns
# 10900001090000

# %%
df['Price'].mean()

df['Price'].idxmax()

df.iloc[[df['Price'].idxmax()]]

df.iloc[[df['Price'].idxmax()]]['locality']
# Out:
# 4400    gembloux
# Name: locality, dtype: object

# %%
df['Number_bedrooms'].value_counts()

# %%
df.iloc[[3]]
df.loc[:3]
# Out:
#               locality   Price       Type_property Sale_type Number_bedrooms  \
# 0   libramont-chevigny  145500           apartment  for-sale               1
# 1  la-roche-en-ardenne  185000  mixed-use-building  for-sale               4
# 2               manhay  228000           apartment  for-sale               4
# 3              bertrix  249500               house  for-sale               3
#
#   Living_area fully_equipped_kitchen Furnished terrace garden surface_land  \
# 0          40                      1         0       8   None           40
# 1         226                      1      None    None   None          226
# 2         290                      0         0    None    300          290
# 3         176                      1         0      18    620          176
#
#   surface_area_plot facades_number Swimming_pool building_state fire_place
# 0              None           None             0           Good       None
# ...

# %%
df.sort_values(by='Living_area', ascending = False).head()
# Out:
#        locality   Price Type_property Sale_type Number_bedrooms Living_area  \
# 13065     diest  295000        duplex  for-sale            None        None
# 7266       bree  650000     penthouse  for-sale            None        None
# 17763     engis  115000         house  for-sale            None        None
# 55137  oostende  175000     apartment  for-sale            None        None
# 7261     lommel  280773     apartment  for-sale            None        None
#
#       fully_equipped_kitchen Furnished terrace garden surface_land  \
# 13065                      1         0       3   None         None
# 7266                    None         0    None   None         None
# 17763                   None      None    None   None         None
# 55137                   None         0    None   None         None
# 7261                    None         0    None   None         None
#
#       surface_area_plot facades_number Swimming_pool building_state fire_place
# ...

# %%
df[(df['Price'] < 400000) & (df['Type_property'] == 'apartment')].sort_values(by = 'Price').head()
# Out:
#              locality  Price Type_property Sale_type Number_bedrooms  \
# 30417  aiseau-presles  25000     apartment  for-sale            None
# 25568       bruxelles  28000     apartment  for-sale               2
# 26603      marcinelle  30000     apartment  for-sale            None
# 18797     la-calamine  40000     apartment  for-sale            None
# 30266          boussu  45000     apartment  for-sale            None
#
#       Living_area fully_equipped_kitchen Furnished terrace garden  \
# 30417        None                      1         0      10   None
# 25568          86                      0      None       3   None
# 26603        None                   None         0    None   None
# 18797        None                   None      None    None   None
# 30266        None                   None      None    None   None
#
#       surface_land surface_area_plot facades_number Swimming_pool  \
# 30417         None              None           None          None
# ...

# %%
df.groupby(by = 'locality')['Price'].mean().head().round(2)
# Out:
# locality
# 1000-bruxelles-ville    545000.00
# aaigem                  307333.33
# aalbeke                 268500.00
# aalst                   350949.79
# aalst-9300              307000.00
# Name: Price, dtype: float64

# %%
for index, row in df.iterrows():
    print(row)
    if index == 3:
        break
# Out:
# locality                  libramont-chevigny
# Price                                 145500
# Type_property                      apartment
# Sale_type                           for-sale
# Number_bedrooms                            1
# Living_area                               40
# fully_equipped_kitchen                     1
# Furnished                                  0
# terrace                                    8
# garden                                  None
# surface_land                              40
# surface_area_plot                       None
# facades_number                          None
# Swimming_pool                              0
# building_state                          Good
# fire_place                              None
# Name: 0, dtype: object
# locality                  la-roche-en-ardenne
# Price                                  185000
# Type_property              mixed-use-building
# Sale_type                            for-sale
# ...

# %%
df[['Price', 'locality']].head()
# Out:
#     Price             locality
# 0  145500   libramont-chevigny
# 1  185000  la-roche-en-ardenne
# 2  228000               manhay
# 3  249500              bertrix
# 4  295000         saint-hubert

# %%
df[100:103]
# Out:
#           locality   Price Type_property Sale_type Number_bedrooms  \
# 100     houffalize  145000         house  for-sale               3
# 101   saint-hubert  169000         house  for-sale               2
# 102  vaux-sur-sure  315000         house  for-sale               4
#
#     Living_area fully_equipped_kitchen Furnished terrace garden surface_land  \
# 100         196                   None         0    None   None          196
# 101          77                   None         0    None   None           77
# 102         253                   None         0    None   None          253
#
#     surface_area_plot facades_number Swimming_pool  building_state fire_place
# 100               484              4          None     To renovate       None
# 101                48              2          None  Just renovated       None
# 102              1200              4          None   To be done up       None

# %%
df.isnull().sum()
# Out:
# locality                   0
# Price                      0
# Type_property              0
# Sale_type                  0
# Number_bedrooms           34
# Living_area                0
# fully_equipped_kitchen     0
# Furnished                  0
# terrace                    0
# garden                     0
# surface_land              34
# surface_area_plot          0
# facades_number             0
# Swimming_pool              0
# building_state             0
# fire_place                 0
# dtype: int64

# %%
df['Number_bedrooms'].fillna(value = np.nan, inplace = True )

df.isnull().sum()
# Out:
# locality                   0
# Price                      0
# Type_property              0
# Sale_type                  0
# Number_bedrooms           34
# Living_area                0
# fully_equipped_kitchen     0
# Furnished                  0
# terrace                    0
# garden                     0
# surface_land              34
# surface_area_plot          0
# facades_number             0
# Swimming_pool              0
# building_state             0
# fire_place                 0
# dtype: int64
